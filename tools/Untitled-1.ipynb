# %%
f = open("./font2.txt")

lines = []
for line in f:
    lines.append(line)

# %%
f
# Out:
# <_io.TextIOWrapper name='./font2.txt' mode='r' encoding='cp1252'>

# %%
print( lines[0][1])
# Out:
# -

# %%
import numpy as np

pData = []
for line in lines:
    row = []
    for c in line:
        if c == "-":
            row.append(0)
        if c == "#":
            row.append(1)
    pData.append(row)

# %%
data = np.array(pData)

# %%
print(pData[1])
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]

# %%
import matplotlib.pyplot as plt 
import base64

h = 8

for i in range(len(lines[:16])):
    chardata = pData[i * h :(i+1 )* h]
    encoded = []
    bitmap = []

    for j in range(h):
        # encoded.append(int(chardata[j][k*4:(k+1)*4], 2))
        binarystr = str(chardata[j]).replace(",","").replace("[","").replace("]","").replace(" ","")
        print(binarystr)
        encoded.append(int(binarystr, 2))
  
    print(i)
    print(encoded)
    plt.matshow(data[i*h:(i+1)*h])
plt.show()
# Out:
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 0
# [0, 0, 0, 0, 0, 0, 0, 0]
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 00000000
# 11111111
# 11111111
# 1
# [0, 0, 0, 0, 0, 0, 255, 255]
# 00000000
# 00000000
# 00000000
# 00000000
# 11111111
# 11111111
# 11111111
# 11111111
# 2
# [0, 0, 0, 0, 255, 255, 255, 255]
# 00000000
# 11111111
# 11111111
# 11111111
# 11111111
# 11111111
# 11111111
# 11111111
# 3
# [0, 255, 255, 255, 255, 255, 255, 255]
# 00000000
# 00100010
# 00100010
# 00010100
# 00010100
# 00001000
# 00001000
# 00000000
# 4
# [0, 34, 34, 20, 20, 8, 8, 0]
# 00000000
# 00011110
# 00000010
# 00000010
# 00000010
# 00000010
# 00000010
# 00000000
# 5
# [0, 30, 2, 2, 2, 2, 2, 0]
# 00100010
# 00100010
# 00111110
# 00100010
# 00100010
# 00010100
# 00001000
# 00000000
# 6
# [34, 34, 62, 34, 34, 20, 8, 0]
# 00011110
# 00000010
# 00000010
# 00001110
# 00000010
# 00000010
# 00011110
# 00000000
# 7
# [30, 2, 2, 14, 2, 2, 30, 0]
# ...
